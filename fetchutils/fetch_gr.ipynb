# %%
import pandas as pd
import requests
import json

# %%
headers = {
    'Accept': 'application/json',
    'Content-Type': 'application/json'#,
    # 'Authorization': f'Bearer ' + token,
}

# %%
endpointUrl = 'https://services1.arcgis.com/YAuo6vcW85VPu7OE/ArcGIS/rest/services/Fallzahlen_Pro_Region/FeatureServer/0/query?'

# %%
params = (
    #('limit', f'{limit}'),
    #('offset', f'{offset}'),
    ('where','1=1'),
    # ('objectIds',''),
    # ('time',''),
    # ('resultType','none'),
    ('outFields','*'),
    # ('returnIdsOnly','false'),
    # ('returnUniqueIdsOnly','false'),
    # ('returnCountOnly','false'),
    # ('returnDistinctValues','false'),
    # ('cacheHint','false'),
    # ('orderByFields','FID%20ASC'),
    # ('groupByFieldsForStatistics',''),
    # ('outStatistics',''),
    # ('having',''),
    # ('resultOffset',0),
    # ('resultRecordCount',50),
    # ('sqlFormat','none'),
    # ('pjson',''),
    # ('token','')
)

# %% [markdown]
# # URL
#
#
# https://services1.arcgis.com/YAuo6vcW85VPu7OE/ArcGIS/rest/services/Fallzahlen_Pro_Region/FeatureServer/0/query?f=json
#
#         &where=1%3D1
#
#         &outFields=*
#
#         &orderByFields=FID%20ASC
#
#         &resultOffset=474
#
#         &resultRecordCount=50
#
#         &cacheHint=true
#
#         &quantizationParameters=%7B%22mode%22%3A%22edit%22%7D

# %%
import requests

params = (
    ('f', 'json'),
    ('where', '1=1'),
    ('outFields', '*'),
)
try:
    response = requests.get('https://services1.arcgis.com/YAuo6vcW85VPu7OE/ArcGIS/rest/services/Fallzahlen_Pro_Region/FeatureServer/0/query', params=params)
    print(response.json())
except:
    print('oh ohw.')

#NB. Original query string below. It seems impossible to parse and
#reproduce query strings 100% accurately so the one below is given
#in case the reproduced version is not "correct".
# response = requests.get('https://services1.arcgis.com/YAuo6vcW85VPu7OE/ArcGIS/rest/services/Fallzahlen_Pro_Region/FeatureServer/0/query?f=json&where=1%3D1&outFields=*')
# Out:
# , 'Neue_Faelle': 0, 'Aktive_Faelle': 0, 'Faelle__kumuliert_': 65, 'Verstorbene': 0, 'Verstorbene__kumuliert_': 1, 'FID': 1896}}, {'attributes': {'Datum': 1596326400000, 'Region': 'Albula', 'Neue_Faelle': 0, 'Aktive_Faelle': 0, 'Faelle__kumuliert_': 10, 'Verstorbene': 0, 'Verstorbene__kumuliert_': 1, 'FID': 1897}}, {'attributes': {'Datum': 1596326400000, 'Region': 'Bernina', 'Neue_Faelle': 0, 'Aktive_Faelle': 1, 'Faelle__kumuliert_': 68, 'Verstorbene': 0, 'Verstorbene__kumuliert_': 3, 'FID': 1898}}, {'attributes': {'Datum': 1596326400000, 'Region': 'Engiadina Bassa/Val Müstair', 'Neue_Faelle': 0, 'Aktive_Faelle': 0, 'Faelle__kumuliert_': 36, 'Verstorbene': 0, 'Verstorbene__kumuliert_': 2, 'FID': 1899}}, {'attributes': {'Datum': 1596326400000, 'Region': 'Imboden', 'Neue_Faelle': 0, 'Aktive_Faelle': 8, 'Faelle__kumuliert_': 49, 'Verstorbene': 0, 'Verstorbene__kumuliert_': 0, 'FID': 1900}}, {'attributes': {'Datum': 1596326400000, 'Region': 'Landquart', 'Neue_Faelle': 0, 'Aktive_Faelle': 
# ...

# %%
print(response.status_code)
# Out:
# 200

# %%
print(response.apparent_encoding)
# Out:
# utf-8

# %%
print(response.content)
# Out:
# ID":1886}},{"attributes":{"Datum":1596240000000,"Region":"Engiadina Bassa/Val M\xc3\xbcstair","Neue_Faelle":0,"Aktive_Faelle":0,"Faelle__kumuliert_":36,"Verstorbene":0,"Verstorbene__kumuliert_":2,"FID":1887}},{"attributes":{"Datum":1596240000000,"Region":"Imboden","Neue_Faelle":2,"Aktive_Faelle":12,"Faelle__kumuliert_":49,"Verstorbene":0,"Verstorbene__kumuliert_":0,"FID":1888}},{"attributes":{"Datum":1596240000000,"Region":"Landquart","Neue_Faelle":0,"Aktive_Faelle":13,"Faelle__kumuliert_":95,"Verstorbene":0,"Verstorbene__kumuliert_":5,"FID":1889}},{"attributes":{"Datum":1596240000000,"Region":"Maloja","Neue_Faelle":2,"Aktive_Faelle":7,"Faelle__kumuliert_":237,"Verstorbene":0,"Verstorbene__kumuliert_":9,"FID":1890}},{"attributes":{"Datum":1596240000000,"Region":"Moesa","Neue_Faelle":0,"Aktive_Faelle":2,"Faelle__kumuliert_":85,"Verstorbene":0,"Verstorbene__kumuliert_":11,"FID":1891}},{"attributes":{"Datum":1596240000000,"Region":"Plessur","Neue_Faelle":1,"Aktive_Faelle":3,"Faelle__kum
# ...

# %%
print(response.headers)
# Out:
# {'Content-Type': 'text/plain; charset=utf-8', 'Content-Length': '18665', 'Connection': 'keep-alive', 'Cache-Control': 'public, max-age=30, s-maxage=30', 'Content-Encoding': 'gzip', 'Last-Modified': 'Wed, 17 Mar 2021 21:37:03 GMT', 'ETag': 'sd2980_-986462772', 'Server': 'Microsoft-IIS/10.0', 'x-esri-query-request-units': '2', 'X-ArcGIS-Correlation-Id': '|5111e5b80f498545a0fa4964f0013b61.de9d9b1d_', 'X-ArcGIS-Instance': 'MTSDS_Web_IN_48', 'Strict-Transport-Security': 'max-age=63072000', 'X-Powered-By': 'ASP.NET', 'Access-Control-Allow-Origin': '*', 'Date': 'Wed, 17 Mar 2021 22:21:24 GMT', 'X-Cache': 'RefreshHit from cloudfront', 'Via': '1.1 8455bcb2c0203b0c4ee93b610d75e69b.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'ZRH50-C1', 'X-Amz-Cf-Id': 'R2JNzkXlbKuB_uxvbI6YYbuGpIIVGtB2ieaZfleAmKIbtpC1A7c_CA=='}

# %%
print(response.iter_content())
# Out:
# <generator object iter_slices at 0x000001B8203F2E40>

# %%
print(response.json())
# Out:
# , 'Neue_Faelle': 0, 'Aktive_Faelle': 0, 'Faelle__kumuliert_': 65, 'Verstorbene': 0, 'Verstorbene__kumuliert_': 1, 'FID': 1896}}, {'attributes': {'Datum': 1596326400000, 'Region': 'Albula', 'Neue_Faelle': 0, 'Aktive_Faelle': 0, 'Faelle__kumuliert_': 10, 'Verstorbene': 0, 'Verstorbene__kumuliert_': 1, 'FID': 1897}}, {'attributes': {'Datum': 1596326400000, 'Region': 'Bernina', 'Neue_Faelle': 0, 'Aktive_Faelle': 1, 'Faelle__kumuliert_': 68, 'Verstorbene': 0, 'Verstorbene__kumuliert_': 3, 'FID': 1898}}, {'attributes': {'Datum': 1596326400000, 'Region': 'Engiadina Bassa/Val Müstair', 'Neue_Faelle': 0, 'Aktive_Faelle': 0, 'Faelle__kumuliert_': 36, 'Verstorbene': 0, 'Verstorbene__kumuliert_': 2, 'FID': 1899}}, {'attributes': {'Datum': 1596326400000, 'Region': 'Imboden', 'Neue_Faelle': 0, 'Aktive_Faelle': 8, 'Faelle__kumuliert_': 49, 'Verstorbene': 0, 'Verstorbene__kumuliert_': 0, 'FID': 1900}}, {'attributes': {'Datum': 1596326400000, 'Region': 'Landquart', 'Neue_Faelle': 0, 'Aktive_Faelle': 
# ...

# %%
print(response.ok)
# Out:
# True

# %%
print(response.text)
# Out:
# 6240000000,"Region":"Bernina","Neue_Faelle":0,"Aktive_Faelle":1,"Faelle__kumuliert_":68,"Verstorbene":0,"Verstorbene__kumuliert_":3,"FID":1886}},{"attributes":{"Datum":1596240000000,"Region":"Engiadina Bassa/Val Müstair","Neue_Faelle":0,"Aktive_Faelle":0,"Faelle__kumuliert_":36,"Verstorbene":0,"Verstorbene__kumuliert_":2,"FID":1887}},{"attributes":{"Datum":1596240000000,"Region":"Imboden","Neue_Faelle":2,"Aktive_Faelle":12,"Faelle__kumuliert_":49,"Verstorbene":0,"Verstorbene__kumuliert_":0,"FID":1888}},{"attributes":{"Datum":1596240000000,"Region":"Landquart","Neue_Faelle":0,"Aktive_Faelle":13,"Faelle__kumuliert_":95,"Verstorbene":0,"Verstorbene__kumuliert_":5,"FID":1889}},{"attributes":{"Datum":1596240000000,"Region":"Maloja","Neue_Faelle":2,"Aktive_Faelle":7,"Faelle__kumuliert_":237,"Verstorbene":0,"Verstorbene__kumuliert_":9,"FID":1890}},{"attributes":{"Datum":1596240000000,"Region":"Moesa","Neue_Faelle":0,"Aktive_Faelle":2,"Faelle__kumuliert_":85,"Verstorbene":0,"Verstorbene__kum
# ...

# %%
print(response.url)
# Out:
# https://services1.arcgis.com/YAuo6vcW85VPu7OE/ArcGIS/rest/services/Fallzahlen_Pro_Region/FeatureServer/0/query?f=json&where=1%3D1&outFields=%2A

# %%
print(response.reason)
# Out:
# OK

# %%
# try:
#     response = requests.get(endpointUrl, headers=headers, params=params, timeout = 5)
#     json = response.json()
#     # return json
# except requests.exceptions.HTTPError as errh:
#     print ("Http Error:",errh)
# except requests.exceptions.ConnectionError as errc:
#     print ("Error Connecting:",errc)
# except requests.exceptions.Timeout as errt:
#     print ("Timeout Error:",errt)
# except requests.exceptions.RequestException as err:
#     print ("Oops: Something Else",err)
# except:
#     print("exception")
#     # return None

# %%
response_json = pd.json_normalize(response.json())

# %%
response_json
# Out:
#   objectIdFieldName globalIdFieldName  \
# 0               FID
#
#                                               fields  exceededTransferLimit  \
# 0  [{'name': 'Datum', 'type': 'esriFieldTypeDate'...                   True
#
#                                             features uniqueIdField.name  \
# 0  [{'attributes': {'Datum': 1582675200000, 'Regi...                FID
#
#    uniqueIdField.isSystemMaintained
# 0                              True

# %%
print(response.json()['fields'])
# Out:
# [{'name': 'Datum', 'type': 'esriFieldTypeDate', 'alias': 'Datum', 'sqlType': 'sqlTypeTimestamp2', 'length': 8, 'domain': None, 'defaultValue': None}, {'name': 'Region', 'type': 'esriFieldTypeString', 'alias': 'Region', 'sqlType': 'sqlTypeNVarchar', 'length': 256, 'domain': None, 'defaultValue': None}, {'name': 'Neue_Faelle', 'type': 'esriFieldTypeInteger', 'alias': 'Neue_Faelle', 'sqlType': 'sqlTypeInteger', 'domain': None, 'defaultValue': None}, {'name': 'Aktive_Faelle', 'type': 'esriFieldTypeInteger', 'alias': 'Aktive_Faelle', 'sqlType': 'sqlTypeInteger', 'domain': None, 'defaultValue': None}, {'name': 'Faelle__kumuliert_', 'type': 'esriFieldTypeInteger', 'alias': 'Faelle__kumuliert_', 'sqlType': 'sqlTypeInteger', 'domain': None, 'defaultValue': None}, {'name': 'Verstorbene', 'type': 'esriFieldTypeInteger', 'alias': 'Verstorbene', 'sqlType': 'sqlTypeInteger', 'domain': None, 'defaultValue': None}, {'name': 'Verstorbene__kumuliert_', 'type': 'esriFieldTypeInteger', 'alias': 'Verstor
# ...

# %%
print(response.json()['features'])
# Out:
# ', 'Neue_Faelle': 0, 'Aktive_Faelle': 0, 'Faelle__kumuliert_': 65, 'Verstorbene': 0, 'Verstorbene__kumuliert_': 1, 'FID': 1896}}, {'attributes': {'Datum': 1596326400000, 'Region': 'Albula', 'Neue_Faelle': 0, 'Aktive_Faelle': 0, 'Faelle__kumuliert_': 10, 'Verstorbene': 0, 'Verstorbene__kumuliert_': 1, 'FID': 1897}}, {'attributes': {'Datum': 1596326400000, 'Region': 'Bernina', 'Neue_Faelle': 0, 'Aktive_Faelle': 1, 'Faelle__kumuliert_': 68, 'Verstorbene': 0, 'Verstorbene__kumuliert_': 3, 'FID': 1898}}, {'attributes': {'Datum': 1596326400000, 'Region': 'Engiadina Bassa/Val Müstair', 'Neue_Faelle': 0, 'Aktive_Faelle': 0, 'Faelle__kumuliert_': 36, 'Verstorbene': 0, 'Verstorbene__kumuliert_': 2, 'FID': 1899}}, {'attributes': {'Datum': 1596326400000, 'Region': 'Imboden', 'Neue_Faelle': 0, 'Aktive_Faelle': 8, 'Faelle__kumuliert_': 49, 'Verstorbene': 0, 'Verstorbene__kumuliert_': 0, 'FID': 1900}}, {'attributes': {'Datum': 1596326400000, 'Region': 'Landquart', 'Neue_Faelle': 0, 'Aktive_Faelle':
# ...

# %%
# print('\n'.join(f'{u}: {response.json().get(u)}' for u in response_json.columns))
print('\n'.join(f'{u}' for u in response_json.columns))
# Out:
# objectIdFieldName
# globalIdFieldName
# fields
# exceededTransferLimit
# features
# uniqueIdField.name
# uniqueIdField.isSystemMaintained
